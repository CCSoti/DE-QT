# %%
import pandas as pd
import distance
from pandas import DataFrame, Series
import numpy
import matplotlib
import sqlite3
import sys
# import MySQLdb as mdb
import csv
# %pylab inline
import pandas as pd
import matplotlib.pyplot as pyplot
from IPython.display import HTML
from collections import Counter


from decimal import Decimal
from statistics import *
import math


class Strings_comp(list):
    
    def clear_data(self):
        small_list = []
        for l in self:
            if(l is not None):  
                if(l!=""):
                   if(l!="N/A"):
                    small_list.append(l)                    
        return small_list
    
    def leven(self):
        all_dis = []
        small_list = Strings_comp(self).clear_data()
        for i in range(0, len(small_list)-1):
            cursor = small_list[i]
            for j in range(i+1, len(small_list)-1):
                dis = distance.levenshtein(cursor, small_list[j])
                all_dis.append(dis)
        return all_dis
    
#     normalized --> jaccard
    def jacc(self):
        all_dis = []
        small_list = Strings_comp(self).clear_data()
        for i in range(0, len(small_list)-1):
            cursor = small_list[i]          
            for j in range(i+1, len(small_list)-1):             
                dis = distance.jaccard(cursor, small_list[j])
                all_dis.append(dis)
        
        dict_v = Counter(all_dis).values()        
        return all_dis
    
    def jacc_diff_values(self):
        all_dis = Strings_comp(self).jacc()
        dict_v = Counter(all_dis).values()
        return len(dict_v)
        
    def jacc_max(self):
        all_dis = []
        small_list = Strings_comp(self).clear_data()
        for i in range(0, len(small_list)-1):
            cursor = small_list[i]          
            for j in range(i+1, len(small_list)-1):             
                dis = distance.jaccard(cursor, small_list[j])   
                print
                if (dis!=0.0):
                    all_dis.append(dis)
        return min(all_dis)
    
    def jacc_high_pair(self):
        all_dis = []
        pair = []
        max_jacc = Strings_comp(self).jacc_max()
        small_list = Strings_comp(self).clear_data()
        for i in range(0, len(small_list)-1):
            cursor = small_list[i]          
            for j in range(i+1, len(small_list)-1):             
                dis = distance.jaccard(cursor, small_list[j])
                if (dis == max_jacc):
                    pair.append(cursor)
                    pair.append(small_list[j])
                if (dis!=0.0):
                    all_dis.append(dis)
        return pair[:2]
        
        
    def num_diff_values(self):
        all_diff = []
        small_list = Strings_comp(self).clear_data()
        dict_v = Counter(small_list).values()
        return len(dict_v)
    
    def most_com_value(self):
        small_list = Strings_comp(self).clear_data()
        dict_v = Counter(small_list).values()
        return Counter(small_list).most_common(1)
    
    def com_value_perc(self):
        small_list = Strings_comp(self).clear_data()
        com_value = max(Counter(small_list).values())
        all_values = len(small_list)
        percentage = (com_value/all_values)*100
        return percentage
    
#     the values that are most referenced to the most common value
    def ref_one(self):
        small_list = Strings_comp(self).clear_data()
        ref_value = Strings_comp(self).most_com_value()
        ref_list = sorted(distance.ilevenshtein(ref_value[0][0], small_list)) 
        return ref_list[11:12]
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['median', 'mean']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import unicodedata

class ListTable(list):

    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
        return ''.join(html)

# %%
conn = sqlite3.connect("C:/Users/SilviyaSoti/Documents/4_Level_Course/Project/Prototype/Working/mapping_database.db")
result= conn.execute('select * from mappingapp_sample')
cursor = conn.cursor()

cursor.execute('select * from mappingapp_sample')
allAttr = cursor.fetchall()
sample_code = [attr[1] for attr in allAttr]
sample_location_name = [attr[2] for attr in allAttr]
collection_date = [attr[3] for attr in allAttr]
collector = [attr[4] for attr in allAttr]
sample_notes = [attr[5] for attr in allAttr]
dating_priority = [attr[6] for attr in allAttr]
age = [attr[7] for attr in allAttr]
age_error = [attr[8] for attr in allAttr]
calendar_age = [attr[9] for attr in allAttr]
calendar_error = [attr[10] for attr in allAttr]
lab_code = [attr[11] for attr in allAttr]

# %%
tableS = ListTable()
titlesS = ["Field", "No-Diff.Similarity", "Max Similarity", "Highest Pair", "No-Diff.Values", "Most Common Value(Reference value)", "Common Value(%)", "Reference"]
tableS.append(titlesS) 
strs = Strings_comp(sample_code)
sGrid = Strings_comp(sample_location_name)
burial = Strings_comp(collection_date)
gamma = Strings_comp(collector)
equip = Strings_comp(sample_notes)
# probe_s = Strings_comp(age)
# filen = Strings_comp(age_error)
# s_time = Strings_comp(calendar_age)
# s_durat = Strings_comp(calendar_error)
bng = ["Sample Code", strs.jacc_diff_values(), strs.jacc_max(), strs.jacc_high_pair(), strs.num_diff_values(), strs.most_com_value(), strs.com_value_perc(), strs.ref_one()]
grid = ["Sample Location Name", sGrid.jacc_diff_values(), sGrid.jacc_max(), sGrid.jacc_high_pair(), sGrid.num_diff_values(), sGrid.most_com_value(), sGrid.com_value_perc(), sGrid.ref_one()]
bur = ["Collection Date", burial.jacc_diff_values(), burial.jacc_max(), burial.jacc_high_pair(), burial.num_diff_values(), burial.most_com_value(), burial.com_value_perc(), burial.ref_one()]
gam = ["Collector", gamma.jacc_diff_values(), gamma.jacc_max(), gamma.jacc_high_pair(), gamma.num_diff_values(), gamma.most_com_value(), gamma.com_value_perc(), gamma.ref_one()]
equ = ["Sample Notes", equip.jacc_diff_values(), equip.jacc_max(), equip.jacc_high_pair(), equip.num_diff_values(), equip.most_com_value(), equip.com_value_perc(), equip.ref_one()]
# prob = ["Probe serial No", probe_s.jacc_diff_values(), probe_s.jacc_max(), probe_s.jacc_high_pair(), probe_s.num_diff_values(), probe_s.most_com_value(), probe_s.com_value_perc(), probe_s.ref_one()]
# fil = ["Filename", filen.jacc_diff_values(), filen.jacc_max(), filen.jacc_high_pair(), filen.num_diff_values(), filen.most_com_value(), filen.com_value_perc(), filen.ref_one()]
# sTime = ["Sample Time", s_time.jacc_diff_values(), s_time.jacc_max(), s_time.jacc_high_pair(), s_time.num_diff_values(), s_time.most_com_value(), s_time.com_value_perc(), s_time.ref_one()]
# sDur = ["Sample Duration", s_durat.jacc_diff_values(), s_durat.jacc_max(), s_durat.jacc_high_pair(), s_durat.num_diff_values(), s_durat.most_com_value(), s_durat.com_value_perc(), s_durat.ref_one()]

tableS.append(bng)
tableS.append(grid)
tableS.append(bur)
tableS.append(gam)
tableS.append(equ)
# tableS.append(prob)
# tableS.append(fil)
# tableS.append(sTime)
# tableS.append(sDur)
tableS
# Out:
# [['Field',
#   'No-Diff.Similarity',
#   'Max Similarity',
#   'Highest Pair',
#   'No-Diff.Values',
#   'Most Common Value(Reference value)',
#   'Common Value(%)',
#   'Reference'],
#  ['Sample Code',
#   63,
#   0.125,
#   ['T1DLO03', 'T3ALDO01'],
#   327,
#   [('T7KIN02', 1)],
#   0.3058103975535168,
#   [(3, 'T8LKAN02')]],
#  ['Sample Location Name',
#   186,
#   0.11764705882352944,
#   ['Raasay North (Site A)', 'Raasay North (Site B)'],
#   99,
#   [('Foula', 11)],
#   3.8596491228070176,
#   [(5, 'Bray')]],
#  ['Collection Date',
#   12,
#   0.1428571428571429,
#   ['2013-04-10', '2013-04-17'],
#   62,
#   [('2013-07-01', 16)],
#   5.594405594405594,
#   [(0, '2013-07-01')]],
#  ['Collector',
#   73,
#   0.09999999999999998,
#   ['RCC, MJB & DHR', 'MJB, RCC & MH'],
#   34,
#   [('MJB & RCC', 38)],
#   13.148788927335639,
#   [(0, 'MJB & RCC')]],
#  ['Sample Notes',
#   778,
#   0.023809523809523836,
#   ['Sample taken from a unit of stratified medium to coarse sand that has bedding conformable to the lower bounding surface. There is some hint of rippling. This unit is atop and capped by a diamict. The sample is ~0.5 m lateral distance from T1GFIR02. Note that the sample tube was not completely filled with sediment. Photos: IMG_6072 to IMG_6076 and IMG_6087.',
#    'Sample taken from a unit of stratified medium to coarse sand that has bedding conformable to the lower bounding surface. There is some hint of rippling. This unit is atop and capped by a diamict. The sample is ~0.5 m lateral distance from T1GFIR01. Note that the sample tube was not completely filled with sediment. Photos: IMG_6077 and IMG_6087.'],
#   277,
#   [('no shielding', 3)],
#   1.023890784982935,
#   [(35, 'same location but sampled surface slopes')]]]
