# %%
import pandas as pd
import distance
from pandas import DataFrame, Series
import numpy
import matplotlib
import sqlite3
import sys
# import MySQLdb as mdb
import csv
# %pylab inline
import pandas as pd
import matplotlib.pyplot as pyplot
from IPython.display import HTML
from collections import Counter


from decimal import Decimal
from statistics import *
import math

class Numerical(list):
    
    def clear_data(self):
        small_list = []
        for l in self:
            if(l is not None):                               
                if(l<500):
                  small_list.append(l)                    
        return small_list
    
    def _max_precission_(self): 
        decimals = []  
        small_list = Numerical(self).clear_data()
        for k in small_list:
            dec = abs(Decimal(str(k)).as_tuple().exponent)
            decimals.append(dec)
        return max(decimals)
    
    def _min_precission_(self): 
        decimals = []  
        small_list = Numerical(self).clear_data()
        for k in small_list:
            dec = abs(Decimal(str(k)).as_tuple().exponent)
            decimals.append(dec)
        return min(decimals)
    
    def _mean_precission_(self): 
        decimals = []  
        small_list = Numerical(self).clear_data()
        for k in small_list:
            dec = abs(Decimal(str(k)).as_tuple().exponent)
            decimals.append(dec)
        return mean(decimals)
        
    def _min_value_(self):
        small_list = Numerical(self).clear_data()
        return min(small_list)
        
    def _max_value_(self):
        small_list = Numerical(self).clear_data()
        return max(small_list)
        
    def _strd_dev_(self):
        small_list = Numerical(self).clear_data()
        return pstdev(small_list)
        
    def _mean_(self):
        small_list = Numerical(self).clear_data()
        return mean(small_list)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
class Numerical2(list):
    
    def clear_data(self):
        small_list = []
        for l in self:
            if(l is not None):                      
                small_list.append(l)                    
        return small_list
    
    def _max_precission_(self): 
        decimals = []  
        small_list = Numerical2(self).clear_data()
        for k in small_list:
            dec = abs(Decimal(str(k)).as_tuple().exponent)
            decimals.append(dec)
        return max(decimals)
    
    def _min_precission_(self): 
        decimals = []  
        small_list = Numerical2(self).clear_data()
        for k in small_list:
            dec = abs(Decimal(str(k)).as_tuple().exponent)
            decimals.append(dec)
        return min(decimals)
    
    def _mean_precission_(self): 
        decimals = []  
        small_list = Numerical2(self).clear_data()
        for k in small_list:
            dec = abs(Decimal(str(k)).as_tuple().exponent)
            decimals.append(dec)
        return mean(decimals)
        
    def _min_value_(self):
        small_list = Numerical2(self).clear_data()
        return min(small_list)
        
    def _max_value_(self):
        small_list = Numerical2(self).clear_data()
        return max(small_list)
        
    def _strd_dev_(self):
        small_list = Numerical2(self).clear_data()
        return pstdev(small_list)
        
    def _mean_(self):
        small_list = Numerical2(self).clear_data()
        return mean(small_list)

# %%
class Strings_comp(list):
    
    def clear_data(self):
        small_list = []
        for l in self:
            if(l is not None):  
                if(l!=""):
                    small_list.append(l)                    
        return small_list
    
    def leven(self):
        all_dis = []
        small_list = Strings_comp(self).clear_data()
        for i in range(0, len(small_list)-1):
            cursor = small_list[i]
            for j in range(i+1, len(small_list)-1):
                dis = distance.levenshtein(cursor, small_list[j])
                all_dis.append(dis)
        return all_dis
    
#     normalized --> jaccard
    def jacc(self):
        all_dis = []
        small_list = Strings_comp(self).clear_data()
        for i in range(0, len(small_list)-1):
            cursor = small_list[i]          
            for j in range(i+1, len(small_list)-1):             
                dis = distance.jaccard(cursor, small_list[j])
                all_dis.append(dis)
        
        dict_v = Counter(all_dis).values()        
        return all_dis
    
    def jacc_diff_values(self):
        all_dis = Strings_comp(self).jacc()
        dict_v = Counter(all_dis).values()
        return len(dict_v)
        
    def jacc_max(self):
        all_dis = []
        small_list = Strings_comp(self).clear_data()
        for i in range(0, len(small_list)-1):
            cursor = small_list[i]          
            for j in range(i+1, len(small_list)-1):             
                dis = distance.jaccard(cursor, small_list[j])   
                print
                if (dis!=0.0):
                    all_dis.append(dis)
        return min(all_dis)
    
    def jacc_high_pair(self):
        all_dis = []
        pair = []
        max_jacc = Strings_comp(self).jacc_max()
        small_list = Strings_comp(self).clear_data()
        for i in range(0, len(small_list)-1):
            cursor = small_list[i]          
            for j in range(i+1, len(small_list)-1):             
                dis = distance.jaccard(cursor, small_list[j])
                if (dis == max_jacc):
                    pair.append(cursor)
                    pair.append(small_list[j])
                if (dis!=0.0):
                    all_dis.append(dis)
        return pair[:2]
        
        
    def num_diff_values(self):
        all_diff = []
        small_list = Strings_comp(self).clear_data()
        dict_v = Counter(small_list).values()
        return len(dict_v)
    
    def most_com_value(self):
        small_list = Strings_comp(self).clear_data()
        dict_v = Counter(small_list).values()
        return Counter(small_list).most_common(1)
    
    def com_value_perc(self):
        small_list = Strings_comp(self).clear_data()
        com_value = max(Counter(small_list).values())
        all_values = len(small_list)
        percentage = (com_value/all_values)*100
        return percentage
    
#     the values that are most referenced to the most common value
    def ref_one(self):
        small_list = Strings_comp(self).clear_data()
        ref_value = Strings_comp(self).most_com_value()
        ref_list = sorted(distance.ilevenshtein(ref_value[0][0], small_list, max_dist=1)) 
        return ref_list[11:14]

# %%
import unicodedata

class ListTable(list):

    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
        return ''.join(html)

# %%
conn = sqlite3.connect("C:/Users/SilviyaSoti/Documents/4_Level_Course/Project/codemets.db")
result= conn.execute('select * from mappingapp_sample')
cursor = conn.cursor()

cursor.execute('select * from mappingapp_coordinates')
allAttr = cursor.fetchall()
ids = [attr[0] for attr in allAttr]
bng_ing = [attr[1] for attr in allAttr]
grid_ref = [attr[2] for attr in allAttr]
easting = [attr[3] for attr in allAttr]
northing = [attr[4] for attr in allAttr]
lat = [attr[5] for attr in allAttr]
longs = [attr[6] for attr in allAttr]
elevation = [attr[7] for attr in allAttr]

# %%
table = ListTable()
titles = ["Field", "Max Value", "Min Value", "Avg Value", "Max Precission", "Min Precission", "Avg Precission", "Std Deviation"]
table.append(titles) 
num = Numerical(lat)
nlong = Numerical(longs)
nEast = Numerical2(easting)
nNorth = Numerical2(northing)
latitude = ["Latitude", num._max_value_(), num._min_value_(), num._mean_(), num._max_precission_(), num._min_precission_(), round(num._mean_precission_()), num._strd_dev_()]
longitude = ["Longitude", nlong._max_value_(), nlong._min_value_(), nlong._mean_(), nlong._max_precission_(), nlong._min_precission_(), round(nlong._mean_precission_()), nlong._strd_dev_()]
east = ["Easting", nEast._max_value_(), nEast._min_value_(), round(nEast._mean_()), nEast._max_precission_(), nEast._min_precission_(), round(nEast._mean_precission_()), nEast._strd_dev_()]
north = ["Northing", nNorth._max_value_(), nNorth._min_value_(), round(nNorth._mean_()), nNorth._max_precission_(), nNorth._min_precission_(), round(nNorth._mean_precission_()), nNorth._strd_dev_()]
table.append(latitude)
table.append(longitude)
table.append(east)
table.append(north)
table
# Out:
# [['Field',
#   'Max Value',
#   'Min Value',
#   'Avg Value',
#   'Max Precission',
#   'Min Precission',
#   'Avg Precission',
#   'Std Deviation'],
#  ['Latitude',
#   60.329613,
#   49.96676,
#   55.39122528030303,
#   6,
#   1,
#   5,
#   2.516513668688992],
#  ['Longitude',
#   -0.068,
#   -10.16472,
#   -5.597611214324324,
#   7,
#   1,
#   5,
#   2.5991755314002165],
#  ['Easting', 528627, 925, 199350, 0, 0, 0, 174734.70774650172],
#  ['Northing', 1160801, 861, 254861, 0, 0, 0, 238487.3834917601]]

# %%
tableS = ListTable()
titlesS = ["Field", "No-Diff.Similarity", "Max Similarity", "Highest Pair", "No-Diff.Values", "Most Common Value(Reference value)", "Common Value(%)", "Reference"]
tableS.append(titlesS) 
strs = Strings_comp(bng_ing)
sGrid = Strings_comp(grid_ref)
sElev = Strings_comp(elevation)
bng = ["Bng Ing", strs.jacc_diff_values(), strs.jacc_max(), strs.jacc_high_pair(), strs.num_diff_values(), strs.most_com_value(), strs.com_value_perc(), strs.ref_one()]
grid = ["Grid Reference", sGrid.jacc_diff_values(), sGrid.jacc_max(), sGrid.jacc_high_pair(), sGrid.num_diff_values(), sGrid.most_com_value(), sGrid.com_value_perc(), sGrid.ref_one()]
elev = ["Elevation", sElev.jacc_diff_values(), sElev.jacc_max(), sElev.jacc_high_pair(), sElev.num_diff_values(), sElev.most_com_value(), sElev.com_value_perc(), sElev.ref_one()]
tableS.append(bng)
tableS.append(grid)
tableS.append(elev)
tableS
# Out:
# [['Field',
#   'No-Diff.Similarity',
#   'Max Similarity',
#   'Highest Pair',
#   'No-Diff.Values',
#   'Most Common Value(Reference value)',
#   'Common Value(%)',
#   'Reference'],
#  ['Bng Ing',
#   11,
#   0.15384615384615385,
#   ['ING (prefix G)', 'ING (Prefix G)'],
#   6,
#   [('8 Figure grid coordinate', 91)],
#   50.55555555555556,
#   [(0, '8 Figure grid coordinate'),
#    (0, '8 Figure grid coordinate'),
#    (0, '8 Figure grid coordinate')]],
#  ['Grid Reference',
#   59,
#   0.09090909090909094,
#   ['SD 55635, 23983', 'SD 55564, 23988'],
#   90,
#   [('SV887164', 6)],
#   4.10958904109589,
#   []],
#  ['Elevation',
#   61,
#   0.1428571428571429,
#   ['140-160 m', '40-60 m'],
#   213,
#   [('6 m', 10)],
#   2.4752475247524752,
#   [(1, '0 m'), (1, '0 m'), (1, '1 m')]]]

# %%
distance.jaccard('a','b', 'z')
# Out:
# 0.875
